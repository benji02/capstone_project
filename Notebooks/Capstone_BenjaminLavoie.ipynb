# %%
# Benjamin Lavoie (benjaminlavoie02@gmail.com)
# Capstone project
# Last update: February 14th, 2024

# %%
# importing libraries

import numpy as np
import pandas as pd
import glob
import os

# %%
path = ''
all_files = glob.glob(os.path.join("DataSets/*.csv"))

all_files
# Out:
# ['DataSets/metacritic_games.csv',
#  'DataSets/metacritic_games_master.csv',
#  'DataSets/reviews.csv',
#  'DataSets/Tagged-Data-Final.csv',
#  'DataSets/Cleaned Data 2.csv',
#  'DataSets/opencritic_rankings_feb_2023.csv',
#  'DataSets/games.csv',
#  'DataSets/metacritic_critic_reviews.csv',
#  'DataSets/all_video_games(cleaned).csv',
#  'DataSets/Raw Data.csv',
#  'DataSets/metacritic_reviews_master.csv',
#  'DataSets/metacritic_reviews.csv']

# %%
df1 = pd.read_csv(all_files[0])
df2 = pd.read_csv(all_files[1], index_col=None, header=0)
df3 = pd.read_csv(all_files[2], index_col=None, header=0)
df4 = pd.read_csv(all_files[3], index_col=None, header=0)
df5 = pd.read_csv(all_files[4], index_col=None, header=0)
df6 = pd.read_csv(all_files[5], index_col=None, header=0)
df7 = pd.read_csv(all_files[6], index_col=None, header=0)
df8 = pd.read_csv(all_files[7], index_col=None, header=0)
df9 = pd.read_csv(all_files[8], index_col=None, header=0)
df10 = pd.read_csv(all_files[9], index_col=None, header=0)
df11 = pd.read_csv(all_files[10], index_col=None, header=0)
df12 = pd.read_csv(all_files[11], index_col=None, header=0)

# %%
display(df1.head())
display(df2.head())
display(df3.head())
# Out:
#    Unnamed: 0                                  game  release_date  \
# 0           0  The Legend of Zelda: Ocarina of Time  Nov 23, 1998
# 1           1              Tony Hawk's Pro Skater 2  Sep 20, 2000
# 2           2                   Grand Theft Auto IV  Apr 29, 2008
# 3           3                           SoulCalibur  Sep  8, 1999
# 4           4                   Grand Theft Auto IV  Apr 29, 2008
#
#                                           genre      platforms  \
# 0                     Action Adventure, Fantasy    Nintendo 64
# 1            Sports, Alternative, Skateboarding    PlayStation
# 2  Action Adventure, Modern, Modern, Open-World  PlayStation 3
# 3                          Action, Fighting, 3D      Dreamcast
# 4  Action Adventure, Modern, Modern, Open-World       Xbox 360
#
#                  developer esrb_rating  \
# 0                 Nintendo           E
# 1  Neversoft Entertainment           T
# 2           Rockstar North           M
# ...

# %%
# df1, metacritic_games: no columns
# df2, metacritic_games_master: all columns
# df3, reviews.csv: no columns



display(df4.head())
display(df5.head())
display(df6.head())
# Out:
#                       Name  Year_of_Release         Genre   Publisher  \
# 0  .hack//Infection Part 1           2002.0  Role-Playing       Atari
# 1   .hack//Mutation Part 2           2002.0  Role-Playing       Atari
# 2   .hack//Outbreak Part 3           2002.0  Role-Playing       Atari
# 3              [Prototype]           2009.0        Action  Activision
# 4              [Prototype]           2009.0        Action  Activision
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0      0.49      0.38      0.26         0.13          1.27          75.0
# 1      0.23      0.18      0.20         0.06          0.68          76.0
# 2      0.14      0.11      0.17         0.04          0.46          70.0
# 3      0.84      0.35      0.00         0.12          1.31          78.0
# 4      0.65      0.40      0.00         0.19          1.24          79.0
#
#    Critic_Count  User_Score  User_Count              Developer Rating  \
# ...

# %%
# df4, Tagged-Data-Final: nice sales and story/gameplay focus columns
# df5, Cleaned Data 2: no columns
# df6, opencritic_rankings_feb_2023: good for opend critic reviews




display(df7.head())
display(df8.head())
display(df9.head())
# Out:
#      AppID                   Name  Release date Estimated owners  Peak CCU  \
# 0    20200       Galactic Bowling  Oct 21, 2008        0 - 20000         0
# 1   655370           Train Bandit  Oct 12, 2017        0 - 20000         0
# 2  1732930           Jolt Project  Nov 17, 2021        0 - 20000         0
# 3  1355720               Henosis™  Jul 23, 2020        0 - 20000         0
# 4  1139950  Two Weeks in Painland   Feb 3, 2020        0 - 20000         0
#
#    Required age  Price  DLC count  \
# 0             0  19.99          0
# 1             0   0.99          0
# 2             0   4.99          0
# 3             0   5.99          0
# 4             0   0.00          0
#
#                                       About the game  \
# 0  Galactic Bowling is an exaggerated and stylize...
# 1  THE LAW!! Looks to be a showdown atop a train....
# 2  Jolt Project: The army now has a new robotics ...
# 3  HENOSIS™ is a mysterious 2D Platform Puzzler w...
# ...

# %%
# df7, games: good for prices, genres and tags
# df8, metacritic_critic_reviews: Doesn't seem too useful as of now
# df9, all_video_games(cleaned): nice for genres splitted and maybe platforms and ratings


display(df10.head())
display(df11.head())
display(df12.head())
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
# df10, Raw Data: Not using
# df11: metacritic_reviews_master:  Too specific, not using
# df12: metacritic_reviews: Too specific, not using
